# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitpreet9435-gif/northstar-operational-data-overview/blob/main/03_Dataset_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Required Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Dataset Files from GitHub

# %%
# Import datasets from GitHub

app_events = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/app_events.csv")

complaints = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/complaints.csv")

customers = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/customers.csv")

data_dictionary = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/data_dictionary.csv")

deliveries = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/deliveries.csv")

drivers = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/drivers.csv")

hubs = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/hubs.csv")

incidents = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/incidents.csv")

orders = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/orders.csv")

vehicles = pd.read_csv("https://raw.githubusercontent.com/mohitpreet9435-gif/Dataset/main/vehicles.csv")

print(vehicles)
# Out:
#     vehicle_id vehicle_type assigned_zone      commission_date  \
# 0         V001           EV         North  2024-12-28 23:48:00
# 1         V002           EV       AIRPORT  2024-04-21 16:14:00
# 2         V003     CargoVan         north  2025-11-24 23:59:00
# 3         V004       Hybrid     RiverSide  2024-06-07 13:21:00
# 4         V005     CargoVan          West  2025-11-15 11:08:00
# ..         ...          ...           ...                  ...
# 115       V116       Diesel          EAST  2025-04-23 07:10:00
# 116       V117       Hybrid         SOUTH  2025-01-11 11:13:00
# 117       V118       Diesel     Riverside  2025-02-18 12:40:00
# 118       V119           EV     RiverSide  2025-08-17 06:19:00
# 119       V120           EV       CENTRAL  2025-05-02 16:13:00
#
#      battery_health_pct  odometer_km maintenance_status telematics_version
# 0                  71.8        56928             Active               v2.2
# ...

# %% [markdown]
# # Display Dataset Preview

# %%
# Preview datasets

print("Customers Dataset")
display(customers.head())

print("Deliveries Dataset")
display(deliveries.head())

print("Orders Dataset")
display(orders.head())
# Out:
# Customers Dataset
#   customer_id  age  home_zone customer_type          signup_date  \
# 0       C0001   26      North           SME  2024-11-27 04:25:00
# 1       C0002   61    AIRPORT      Consumer  2025-10-28 01:04:00
# 2       C0003   66       East      Consumer  2025-07-02 03:23:00
# 3       C0004   75    CENTRAL      Consumer  2025-08-19 01:58:00
# 4       C0005   26  Riverside      Consumer  2025-06-03 06:02:00
#
#    loyalty_score  app_engagement_score preferred_channel account_status
# 0           44.9                  69.2               App         Active
# 1           55.4                  66.6               App         Active
# 2           75.9                  33.8               NaN         Active
# 3           32.5                  33.0               App         Active
# 4           55.9                 100.0               Web         Active
# Deliveries Dataset
#   delivery_id order_id driver_id vehicle_id hub_id        dispatch_time  \
# ...

# %% [markdown]
# #  Display Dataset Information

# %%
# Dataset structure and information

print("Customers Dataset Info")
customers.info()

print("\nDeliveries Dataset Info")
deliveries.info()

print("\nOrders Dataset Info")
orders.info()
# Out:
# Customers Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           650 non-null    object
#  1   age                   650 non-null    int64
#  2   home_zone             650 non-null    object
#  3   customer_type         650 non-null    object
#  4   signup_date           650 non-null    object
#  5   loyalty_score         630 non-null    float64
#  6   app_engagement_score  650 non-null    float64
#  7   preferred_channel     637 non-null    object
#  8   account_status        650 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 45.8+ KB
#
# Deliveries Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ...

# %% [markdown]
# # Check Missing Values

# %%
# Missing values check

print("Missing Values in Customers Dataset")
print(customers.isnull().sum())

print("\nMissing Values in Deliveries Dataset")
print(deliveries.isnull().sum())

print("\nMissing Values in Orders Dataset")
print(orders.isnull().sum())
# Out:
# Missing Values in Customers Dataset
# customer_id              0
# age                      0
# home_zone                0
# customer_type            0
# signup_date              0
# loyalty_score           20
# app_engagement_score     0
# preferred_channel       13
# account_status           0
# dtype: int64
#
# Missing Values in Deliveries Dataset
# delivery_id                       0
# order_id                          0
# driver_id                         0
# vehicle_id                        0
# hub_id                            0
# dispatch_time                     0
# delivery_completed_at            19
# delivery_status                   0
# route_distance_km                 0
# manual_route_override_count       0
# proof_of_completion_missing       0
# customer_rating_post_delivery    14
# fuel_or_charge_cost               0
# dtype: int64
#
# Missing Values in Orders Dataset
# order_id                  0
# customer_id               0
# service_type              0
# ...

# %% [markdown]
# # Dataset Dimensions

# %%
# Dataset dimensions

print("Customers Shape:", customers.shape)
print("Deliveries Shape:", deliveries.shape)
print("Orders Shape:", orders.shape)
print("Complaints Shape:", complaints.shape)
print("App Events Shape:", app_events.shape)
# Out:
# Customers Shape: (650, 9)
# Deliveries Shape: (950, 13)
# Orders Shape: (1250, 11)
# Complaints Shape: (320, 10)
# App Events Shape: (640, 10)

# %% [markdown]
# # Statistical Summary

# %%
# Statistical summary

display(customers.describe())

display(deliveries.describe())
# Out:
#               age  loyalty_score  app_engagement_score
# count  650.000000     630.000000            650.000000
# mean    46.738462      59.690635             58.132308
# std     17.449179      16.124674             18.918154
# min     18.000000      13.100000              1.000000
# 25%     32.000000      49.000000             45.375000
# 50%     46.000000      59.600000             59.000000
# 75%     62.000000      70.450000             72.000000
# max     78.000000      99.000000            100.000000
#        route_distance_km  manual_route_override_count  \
# count         950.000000                   950.000000
# mean           13.909316                     0.969474
# std             7.477907                     1.093189
# min             1.200000                     0.000000
# 25%             9.135000                     0.000000
# 50%            12.840000                     1.000000
# 75%            16.835000                     2.000000
# ...
